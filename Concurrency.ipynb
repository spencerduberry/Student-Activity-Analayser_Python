# %%
"""def prep_data_call(self):
    if not self.data_loaded:
        messagebox.showerror("Error", "No data loaded. Please load the data first.")
        return

    try:
        input_from_form = self.table_name_entry.get().strip()
        self.get_table_name_gui(input_from_form)

        if self.csv_dict is None:
            messagebox.showerror(
                "Error", "No CSV data available. Please load the data first."
            )
            return

        if not self.data_manager.get_table_name():
            raise ValueError("Table name is not set correctly.")

        thread = threading.Thread(target=self.run_prep_data)
        thread.start()

    except ValueError as ve:
        messagebox.showerror("Error", f"Invalid table name: {ve}")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred during data preparation: {e}")


def run_prep_data(self):
    try:
        prep_data(self.csv_dict, self.data_manager)
        self.data_prepped = True
        self.after(
            0,
            lambda: messagebox.showinfo(
                "Info",
                f"Data successfully prepped! Table name: {self.data_manager.get_table_name()}",
            ),
        )
    except Exception:
        self.after(
            0,
            lambda: messagebox.showerror(
                "Error", f"An error occurred during data preparation: {e}"
            ),
        )"""
# Out:
# Unique entries in the 'Action' column:
# ['Viewed' 'Updated' 'Submitted' 'Uploaded' 'Created' 'viewed' 'Reviewed'
#  'Answered' 'Downloaded' 'Started' 'created' 'uploaded' 'submitted'
#  'Saved' 'Removed' 'updated' 'downloaded' ' ']
#
# Unique entries in the 'Target' column:
# ['Content' 'Response' 'Attempt' 'Assignment' 'Submission_state' 'Feedback'
#  'Submission_status' 'Submission' 'File_submission' 'Activity' 'Course'
#  'Folder' 'Resource' 'Grade' 'Choice' 'Submission ' 'Completion_state'
#  'Report' 'File_submission ' 'Session' 'content' 'session' 'Page' 'URL'
#  'Option' 'Submission_text' 'Quiz' 'Files' 'submission_status'
#  'assignment' 'quiz' 'feedback' 'folder' 'submission' 'file_submission'
#  'choice' 'resource' 'files' 'page' 'attempt' 'response' 'Comment']
# ['17/11/2023 00:00' '10/11/2023 00:00' '20/12/2023 00:00'
#  '23/10/2023 00:00' '16/12/2023 00:00' '09/10/2023 00:00'
#  '24/11/2023 00:00' '27/09/2023 00:00' '23/11/2023 00:00'
# ...
